# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import tensorflow as tf
train = tf.keras.utils.image_dataset_from_directory('/kaggle/input/cifake-real-and-ai-generated-synthetic-images/train', image_size=(32, 32))
# Out:
# 2024-03-14 10:16:14.247564: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-14 10:16:14.247719: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-14 10:16:14.435694: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 100000 files belonging to 2 classes.

# %%
train_data = []
for pic,num in train:
    for j in range(32):
        train_data.append([pic[j],num[j]])

# %%
X_train = []
Y_train = []
for val in train_data:
    X_train.append(val[0]/255)
    Y_train.append(val[1])

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(X_train[0])

# %%
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, add

# %%
X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
model=models.Sequential([
        layers.Conv2D(filters=80,kernel_size=(3,3),padding='same',activation='relu',input_shape=(32,32,3)),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.2)),
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.2)),
        layers.Conv2D(filters=40,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.1)),
        layers.Conv2D(filters=20,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.1)),
        
        layers.Flatten(),
        layers.Dense(64,activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(48,activation='relu'),
        layers.Dropout(0.2),
        
        layers.Dense(2,activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()

# %%
X_train[0].size

# %%
print(len(X_train))
print(len(Y_train))

# %%
model.fit(X_train,Y_train,epochs=10)

# %%
test = tf.keras.utils.image_dataset_from_directory('/kaggle/input/cifake-real-and-ai-generated-synthetic-images/test', image_size=(32, 32))
# Out:
# Found 20000 files belonging to 2 classes.

# %%
test_data = []
for pic,num in test:
    for j in range(32):
        test_data.append([pic[j],num[j]])

# %%
model1=models.Sequential([
        layers.Conv2D(filters=90,kernel_size=(3,3),padding='same',activation='relu',input_shape=(32,32,3)),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=75,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=30,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.1)),
        
        layers.Flatten(),
        layers.Dense(75,activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(50,activation='relu'),
        layers.Dropout(0.2),
        
        layers.Dense(2,activation='sigmoid')
])

model1.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model1.summary()

# %%
model1.fit(X_train,Y_train,epochs=10)

# %%
X_test = []
Y_test = []
for val in test_data:
    X_test.append(val[0]/255)
    Y_test.append(val[1])

# %%
X_test = np.array(X_test)
Y_test = np.array(Y_test)

# %%
y_pred=model1.predict(X_test)

# %%
Y_Pred=[]
for i in range(len(y_pred)):
    y_hat=np.argmax(y_pred[i])
    Y_Pred.append(y_hat)

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_Pred))

# %%
model2=models.Sequential([
        layers.Conv2D(filters=25,kernel_size=(3,3),padding='same',strides = 2,activation='relu',input_shape=(32,32,3)),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=50,kernel_size=(3,3),padding='same',strides = 2,activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=80,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.1)),
        
        layers.Flatten(),
        layers.Dense(90,activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(70,activation='relu'),
        layers.Dropout(0.2),
        
        layers.Dense(2,activation='sigmoid')
])

model2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model2.summary()

# %%
model2.fit(X_train,Y_train,epochs=10)

# %%
y_pred=model2.predict(X_test)
Y_Pred=[]
for i in range(len(y_pred)):
    y_hat=np.argmax(y_pred[i])
    Y_Pred.append(y_hat)
print(classification_report(Y_test,Y_Pred))

# %%
model3=models.Sequential([
        layers.Conv2D(filters=40,kernel_size=(3,3),padding='same',strides = 2,activation='relu',input_shape=(32,32,3)),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=60,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=80,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.1)),
        
        layers.Flatten(),
        layers.Dense(100,activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(60,activation='relu'),
        layers.Dropout(0.2),
        
        layers.Dense(2,activation='sigmoid')
])

model3.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model3.summary()

# %%
model3.fit(X_train,Y_train,epochs=10)

# %%
y_pred=model3.predict(X_test)
Y_Pred=[]
for i in range(len(y_pred)):
    y_hat=np.argmax(y_pred[i])
    Y_Pred.append(y_hat)
print(classification_report(Y_test,Y_Pred))

# %%
model4=models.Sequential([
        layers.Conv2D(filters=25,kernel_size=(3,3),padding='same',strides = 2,activation='relu',input_shape=(32,32,3)),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=50,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=80,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.1)),
        
        layers.Flatten(),
        layers.Dense(90,activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(90,activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(70,activation='relu'),
        layers.Dropout(0.2),
        
        layers.Dense(2,activation='sigmoid')
])

model4.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model4.summary()

# %%
model4.fit(X_train,Y_train,epochs=10)

# %%
y_pred=model4.predict(X_test)
Y_Pred=[]
for i in range(len(y_pred)):
    y_hat=np.argmax(y_pred[i])
    Y_Pred.append(y_hat)
print(classification_report(Y_test,Y_Pred))

# %%
model5=models.Sequential([
        layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',strides = 2,activation='relu',input_shape=(32,32,3)),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=128,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.1)),
        
        layers.Flatten(),
        layers.Dense(64,activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(32,activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(16,activation='relu'),
        layers.Dropout(0.2),
        
        layers.Dense(2,activation='sigmoid')
])

model5.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model5.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 16, 16, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 8, 8, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 4, 4, 64)       │             0 │
# ...

# %%
model5.fit(X_train,Y_train,epochs=10)

# %%
y_pred=model5.predict(X_test)
Y_Pred=[]
for i in range(len(y_pred)):
    y_hat=np.argmax(y_pred[i])
    Y_Pred.append(y_hat)
print(classification_report(Y_test,Y_Pred))

# %%
model6=models.Sequential([
        layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',strides = 2,activation='relu',input_shape=(32,32,3)),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.1)),    
        layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=128,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.1)),
        
        layers.Flatten(),
        layers.Dense(64,activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(16,activation='relu'),
        layers.Dropout(0.2),
        
        layers.Dense(2,activation='sigmoid')
])

model6.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model6.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_27 (Conv2D)              │ (None, 16, 16, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_27 (MaxPooling2D) │ (None, 8, 8, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_42 (Dropout)            │ (None, 8, 8, 16)       │             0 │
# ...

# %%
model6.fit(X_train,Y_train,epochs=10)
# Out:
# Epoch 1/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - accuracy: 0.7489 - loss: 0.4831
# Epoch 2/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 32s 10ms/step - accuracy: 0.8810 - loss: 0.2918
# Epoch 3/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - accuracy: 0.8956 - loss: 0.2625
# Epoch 4/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 32s 10ms/step - accuracy: 0.9015 - loss: 0.2434
# Epoch 5/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - accuracy: 0.9050 - loss: 0.2385
# Epoch 6/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 32s 10ms/step - accuracy: 0.9101 - loss: 0.2266
# Epoch 7/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 32s 10ms/step - accuracy: 0.9131 - loss: 0.2186
# Epoch 8/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 32s 10ms/step - accuracy: 0.9183 - loss: 0.2117
# Epoch 9/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 41s 10ms/step - accuracy: 0.9177 - loss: 0.2104
# Epoch 10/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 32s 10ms/step - accuracy: 0.9210 - loss: 0.2045

# %%
from sklearn.metrics import classification_report
y_pred=model6.predict(X_test)
Y_Pred=[]
for i in range(len(y_pred)):
    y_hat=np.argmax(y_pred[i])
    Y_Pred.append(y_hat)
print(classification_report(Y_test,Y_Pred))
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92     10000
#            1       0.90      0.95      0.93     10000
#
#     accuracy                           0.93     20000
#    macro avg       0.93      0.93      0.93     20000
# weighted avg       0.93      0.93      0.93     20000

# %%
model7=models.Sequential([
        layers.Conv2D(filters=128,kernel_size=(3,3),padding='same',strides = 2,activation='relu',input_shape=(32,32,3)),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.1)),    
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.1)),
        
        layers.Flatten(),
        layers.Dense(64,activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(16,activation='relu'),
        layers.Dropout(0.2),
        
        layers.Dense(2,activation='sigmoid')
])

model7.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model7.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_23 (Conv2D)              │ (None, 16, 16, 128)    │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_36 (Dropout)            │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 8, 8, 64)       │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 4, 4, 64)       │             0 │
# ...

# %%
model7.fit(X_train,Y_train,epochs=10)
# Out:
# Epoch 1/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 83s 26ms/step - accuracy: 0.7547 - loss: 0.4740
# Epoch 2/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 77s 25ms/step - accuracy: 0.8878 - loss: 0.2771
# Epoch 3/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.9058 - loss: 0.2383
# Epoch 4/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 77s 25ms/step - accuracy: 0.9155 - loss: 0.2186
# Epoch 5/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 81s 24ms/step - accuracy: 0.9202 - loss: 0.2029
# Epoch 6/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 77s 24ms/step - accuracy: 0.9241 - loss: 0.1942
# Epoch 7/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 77s 25ms/step - accuracy: 0.9273 - loss: 0.1867
# Epoch 8/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 81s 24ms/step - accuracy: 0.9319 - loss: 0.1777
# Epoch 9/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 74s 24ms/step - accuracy: 0.9339 - loss: 0.1737
# Epoch 10/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 24ms/step - accuracy: 0.9370 - loss: 0.1624

# %%
from sklearn.metrics import classification_report
y_pred=model7.predict(X_test)
Y_Pred=[]
for i in range(len(y_pred)):
    y_hat=np.argmax(y_pred[i])
    Y_Pred.append(y_hat)
print(classification_report(Y_test,Y_Pred))
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.93     10000
#            1       0.90      0.96      0.93     10000
#
#     accuracy                           0.93     20000
#    macro avg       0.93      0.93      0.93     20000
# weighted avg       0.93      0.93      0.93     20000

# %%
model8=models.Sequential([
        layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',strides = 2,activation='relu',input_shape=(32,32,3)),    
        layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.25)),
        layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu'),
        layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.2)),
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout((0.2)),
    
        layers.Flatten(),
        layers.Dense(64,activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(16,activation='relu'),
        layers.Dropout(0.2),
        
        layers.Dense(2,activation='sigmoid')
])

model8.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model8.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_31 (Conv2D)              │ (None, 16, 16, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 16, 16, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_31 (MaxPooling2D) │ (None, 8, 8, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_48 (Dropout)            │ (None, 8, 8, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 8, 8, 32)       │         4,640 │
# ...

# %%
model8.fit(X_train,Y_train,epochs=10)
# Out:
# Epoch 1/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 53s 16ms/step - accuracy: 0.7801 - loss: 0.4489
# Epoch 2/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 49s 16ms/step - accuracy: 0.8930 - loss: 0.2660
# Epoch 3/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 50s 16ms/step - accuracy: 0.9102 - loss: 0.2310
# Epoch 4/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 81s 16ms/step - accuracy: 0.9160 - loss: 0.2136
# Epoch 5/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 16ms/step - accuracy: 0.9198 - loss: 0.2081
# Epoch 6/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 16ms/step - accuracy: 0.9252 - loss: 0.1927
# Epoch 7/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 49s 16ms/step - accuracy: 0.9282 - loss: 0.1886
# Epoch 8/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 49s 16ms/step - accuracy: 0.9308 - loss: 0.1829
# Epoch 9/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 16ms/step - accuracy: 0.9318 - loss: 0.1799
# Epoch 10/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 16ms/step - accuracy: 0.9336 - loss: 0.1753

# %%
from sklearn.metrics import classification_report
y_pred=model8.predict(X_test)
Y_Pred=[]
for i in range(len(y_pred)):
    y_hat=np.argmax(y_pred[i])
    Y_Pred.append(y_hat)
print(classification_report(Y_test,Y_Pred))
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91     10000
#            1       0.87      0.98      0.92     10000
#
#     accuracy                           0.92     20000
#    macro avg       0.92      0.92      0.92     20000
# weighted avg       0.92      0.92      0.92     20000

# %%
model9=models.Sequential([
        layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',strides = 2,activation='relu',input_shape=(32,32,3)),    
        layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu'),
        layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
    
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'), 
        layers.MaxPool2D((2,2)),
    
        layers.Flatten(),
        layers.Dense(64,activation='relu'),
        layers.Dense(16,activation='relu'),
        
        layers.Dense(2,activation='sigmoid')
])

model9.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model9.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 16, 16, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 8, 8, 16)       │             0 │
# ...

# %%
model9.fit(X_train,Y_train,epochs=12)
# Out:
# Epoch 1/12
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 62s 19ms/step - accuracy: 0.7764 - loss: 0.4291
# Epoch 2/12
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 19ms/step - accuracy: 0.9032 - loss: 0.2376
# Epoch 3/12
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 58s 19ms/step - accuracy: 0.9190 - loss: 0.2032
# Epoch 4/12
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 19ms/step - accuracy: 0.9281 - loss: 0.1812
# Epoch 5/12
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 59s 19ms/step - accuracy: 0.9344 - loss: 0.1692
# Epoch 6/12
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 19ms/step - accuracy: 0.9376 - loss: 0.1576
# Epoch 7/12
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 59s 19ms/step - accuracy: 0.9421 - loss: 0.1473
# Epoch 8/12
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 59s 19ms/step - accuracy: 0.9445 - loss: 0.1423
# Epoch 9/12
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 19ms/step - accuracy: 0.9472 - loss: 0.1354
# Epoch 10/12
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 81s 19ms/step - accuracy: 0.9504 - loss: 0.1266
# Epoch 11/12
# ...

# %%
from sklearn.metrics import classification_report
y_pred=model9.predict(X_test)
Y_Pred=[]
for i in range(len(y_pred)):
    y_hat=np.argmax(y_pred[i])
    Y_Pred.append(y_hat)
print(classification_report(Y_test,Y_Pred))
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93     10000
#            1       0.91      0.96      0.94     10000
#
#     accuracy                           0.93     20000
#    macro avg       0.94      0.93      0.93     20000
# weighted avg       0.94      0.93      0.93     20000

# %%
model10=models.Sequential([
        layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',strides = 2,activation='relu',input_shape=(32,32,3)),    
        layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout(0.2),
        layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu'),
        layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu'),
        layers.MaxPool2D((2,2)),
        layers.Dropout(0.2),
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
        layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'), 
        layers.MaxPool2D((2,2)),
        layers.Dropout(0.2),
    
        layers.Flatten(),
        layers.Dense(64,activation='relu'),
        layers.Dense(16,activation='relu'),
        
        layers.Dense(2,activation='sigmoid')
])

model10.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model10.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 16, 16, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 16)       │             0 │
# ...

# %%
model10.fit(X_train,Y_train,epochs=10)
# Out:
# Epoch 1/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 65s 20ms/step - accuracy: 0.7929 - loss: 0.4249
# Epoch 2/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 81s 19ms/step - accuracy: 0.8971 - loss: 0.2508
# Epoch 3/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 61s 20ms/step - accuracy: 0.9137 - loss: 0.2184
# Epoch 4/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 61s 19ms/step - accuracy: 0.9198 - loss: 0.2019
# Epoch 5/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 20ms/step - accuracy: 0.9256 - loss: 0.1900
# Epoch 6/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 20ms/step - accuracy: 0.9298 - loss: 0.1803
# Epoch 7/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 61s 20ms/step - accuracy: 0.9320 - loss: 0.1734
# Epoch 8/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 20ms/step - accuracy: 0.9328 - loss: 0.1699
# Epoch 9/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 81s 19ms/step - accuracy: 0.9365 - loss: 0.1613
# Epoch 10/10
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 82s 19ms/step - accuracy: 0.9374 - loss: 0.1586

# %%
from sklearn.metrics import classification_report
y_pred=model10.predict(X_test)
Y_Pred=[]
for i in range(len(y_pred)):
    y_hat=np.argmax(y_pred[i])
    Y_Pred.append(y_hat)
print(classification_report(Y_test,Y_Pred))
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93     10000
#            1       0.91      0.96      0.94     10000
#
#     accuracy                           0.93     20000
#    macro avg       0.94      0.93      0.93     20000
# weighted avg       0.94      0.93      0.93     20000

# %% [markdown]
# This model10 has higher accuracy among the above ones.
